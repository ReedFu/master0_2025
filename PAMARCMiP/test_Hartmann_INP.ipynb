# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_table(r"D:\Data\PAMARCMiP\Hartmann-etal_2019_INP-PAMARCMIP\datasets\P5_210_PAMARCMIP_2018_1803230301_INP.tab", skiprows=19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 8 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   T tech [°C] (INDA, Ice Nucleation Droplet ...)      406 non-null    float64
#  1   N INP air [#/l] (INDA, Ice Nucleation Droplet ...)  406 non-null    float64
#  2   T tech [°C] (INDA blank, Ice Nucleation Dr...)      345 non-null    float64
#  3   N INP air [#/l] (INDA blank, Ice Nucleation Dr...)  345 non-null    float64
#  4   T tech [°C] (LINA, Leipzig Ice Nucleation ...)      320 non-null    float64
#  5   N INP air [#/l] (LINA, Leipzig Ice Nucleation ...)  320 non-null    float64
#  6   T tech [°C] (LINA blank, Leipzig Ice Nucle...)      281 non-null    float64
#  7   N INP air [#/l] (LINA blank, Leipzig Ice Nucle...)  281 non-null    float64
# dtypes: float64(8)
# memory usage: 25.5 KB

# %%
df.columns
# Out:
# Index(['T tech [°C] (INDA, Ice Nucleation Droplet ...)',
#        'N INP air [#/l] (INDA, Ice Nucleation Droplet ...)',
#        'T tech [°C] (INDA blank, Ice Nucleation Dr...)',
#        'N INP air [#/l] (INDA blank, Ice Nucleation Dr...)',
#        'T tech [°C] (LINA, Leipzig Ice Nucleation ...)',
#        'N INP air [#/l] (LINA, Leipzig Ice Nucleation ...)',
#        'T tech [°C] (LINA blank, Leipzig Ice Nucle...)',
#        'N INP air [#/l] (LINA blank, Leipzig Ice Nucle...)'],
#       dtype='object')

# %%
fig = plt.figure(dpi=500)
ax = fig.add_subplot(111)
ax.set_yscale('log')
ax.set_xlabel('Temperature(℃)')
ax.set_ylabel('INP concentration(#/L)')
ax.tick_params(which='both', top=True, bottom=True, left=True, right=True, direction='in')
fig.suptitle('INP concentration vs Temperature')

x = df[df.columns[0]]
y = df[df.columns[1]]
ax.scatter(x,y)

# %%
fig2 = plt.figure(dpi=500)
ax2 = fig2.add_subplot(111)
ax2.set_yscale('log')
ax2.set_xlabel('Temperature(℃)')
ax2.set_ylabel('INP concentration(#/L)')
ax2.tick_params(which='both', top=True, bottom=True, left=True, right=True, direction='in')
fig2.suptitle('INP concentration vs Temperature')

x2 = df[df.columns[2]]
y2 = df[df.columns[3]]
ax2.scatter(x1,y1)
fig2

# %%
fig = plt.figure(dpi=500)


ax1 = fig.add_subplot(221)
ax1.set_yscale('log')
ax1.set_xlabel('Temperature(℃)')
ax1.set_ylabel('INP concentration(#/L)')
ax1.tick_params(which='both', top=True, bottom=True, left=True, right=True, direction='in')
fig.suptitle('INP concentration vs Temperature')

ax2 = fig.add_subplot(222)
ax2.set_yscale('log')
ax2.set_xlabel('Temperature(℃)')
ax2.set_ylabel('INP concentration(#/L)')
ax2.tick_params(which='both', top=True, bottom=True, left=True, right=True, direction='in')

ax3 = fig.add_subplot(223)
ax3.set_yscale('log')
ax3.set_xlabel('Temperature(℃)')
ax3.set_ylabel('INP concentration(#/L)')
ax3.tick_params(which='both', top=True, bottom=True, left=True, right=True, direction='in')

ax4 = fig.add_subplot(224)
ax4.set_yscale('log')
ax4.set_xlabel('Temperature(℃)')
ax4.set_ylabel('INP concentration(#/L)')
ax4.tick_params(which='both', top=True, bottom=True, left=True, right=True, direction='in')


x1 = df[df.columns[0]]
y1 = df[df.columns[1]]
x2 = df[df.columns[2]]
y2 = df[df.columns[3]]
x3 = df[df.columns[4]]
y3 = df[df.columns[5]]
x4 = df[df.columns[6]]
y4 = df[df.columns[7]]

ax1.scatter(x1,y1)
ax2.scatter(x2,y2)
ax3.scatter(x3,y3)
ax4.scatter(x4,y4)

fig
