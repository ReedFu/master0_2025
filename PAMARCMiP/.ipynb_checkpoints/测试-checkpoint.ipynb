# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_table(r"D:\Data\PAMARCMiP\Sze-etal_2023_NINP.tab", skiprows=286)
T = np.arange(-30.4, -4.4, 0.1)# 自行设置温度区间

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Columns: 268 entries, Sample label to N INP air [#/l] (at -30.4 °C)
# dtypes: float64(262), int64(1), object(5)
# memory usage: 379.1+ KB

# %%
rows, cols = df.shape

# %%
#for row in rows :
x = T
y = df.iloc[0, 8:]

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(dpi=500)
ax.set_yscale('log')
ax.set_xlabel('Temperature(℃)')
ax.set_ylabel('INP concentration(#/L)')
ax.tick_params(which='both', top=True, bottom=True, left=True, right=True, direction='in')
ax.set_title('INP concentration vs Temperature')
ax.scatter(x, y)

# %%
y
# Out:
# N INP air [#/l] (at -7.5 °C)     0.000089
# N INP air [#/l] (at -7.6 °C)     0.000118
# N INP air [#/l] (at -7.7 °C)     0.000129
# N INP air [#/l] (at -7.8 °C)     0.000129
# N INP air [#/l] (at -7.9 °C)     0.000129
#                                    ...
# N INP air [#/l] (at -21.4 °C)    0.096442
# N INP air [#/l] (at -21.5 °C)    0.096442
# N INP air [#/l] (at -21.6 °C)    0.096442
# N INP air [#/l] (at -21.7 °C)    0.101952
# N INP air [#/l] (at -21.8 °C)    0.107939
# Name: 0, Length: 144, dtype: object

# %%
for row in np.arange(rows) :
    x = T
    y = df.iloc[row, 8:]
    ax.scatter(x, y)

# %%
range(rows)
# Out:
# range(0, 181)
