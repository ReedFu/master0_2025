# %%
import pandas as pd

df = pd.read_csv(r"E:\data\FIRE-ACE\CFDC_NCAR C130 Aircraft\fire_ace_cfd_05041998.txt", skiprows=19, sep='\s+')

print(df)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\fubingding\AppData\Local\Temp\ipykernel_7968\1643551290.py:3: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv(r"E:\data\FIRE-ACE\CFDC_NCAR C130 Aircraft\fire_ace_cfd_05041998.txt", skiprows=19, sep='\s+')
#       UTsec  hh:mm:ss    Ts  SSw   SSi     Ps    Qs  IN#    CNconc  INconc
# 0     67861  18:51:01 -25.6 -4.7  22.7  988.5  1.02    0  55029.81   56.83
# 1     67862  18:51:02 -25.6 -4.6  22.8  988.6  1.14    0  48843.97   56.83
# 2     67863  18:51:03 -25.7 -4.5  22.9  988.8  1.18    1  62550.70   56.83
# 3     67864  18:51:04 -25.7 -4.5  22.9  988.6  1.19    1  21577.56    7.98
# 4     67865  18:51:05 -25.7 -4.4  23.1  988.7  1.18    0   9395.35    7.98
# ...     ...       ...   ...  ...   ...    ...   ...  ...       ...     ...
# 7774  13795  03:49:55 -21.5  3.9  28.4  980.0  0.27    0   4357.81   40.31
# ...

# %%
print(df['INconc'])
print(min(df['INconc']))
print(max(df['INconc']))
print(df.info())
# Out:
# 0       56.83
# 1       56.83
# 2       56.83
# 3        7.98
# 4        7.98
#         ...
# 7774    40.31
# 7775    40.31
# 7776    40.31
# 7777    35.04
# 7778    35.04
# Name: INconc, Length: 7779, dtype: float64
# 0.0
# 27796.32
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7779 entries, 0 to 7778
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   UTsec     7779 non-null   int64
#  1   hh:mm:ss  7779 non-null   object
#  2   Ts        7779 non-null   float64
#  3   SSw       7779 non-null   float64
#  4   SSi       7779 non-null   float64
#  5   Ps        7779 non-null   float64
#  6   Qs        7779 non-null   float64
#  7   IN#       7779 non-null   int64
#  8   CNconc    7779 non-null   float64
#  9   INconc    7779 non-null   float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 607.9+ KB
# None
