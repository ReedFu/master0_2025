# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\Coding\Data\ISDAC\brooks-cfdc\080408 - f16 - CFDC - v1.0.txt", sep='\t').astype({'IN Conc (cm-3)': 'float'})
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Time UTC        223 non-null    object
#  1   Aerosol T (C)   223 non-null    float64
#  2   SS.Water (%)    223 non-null    float64
#  3   SS. Ice (%)     223 non-null    float64
#  4   IN Conc (cm-3)  82 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 8.8+ KB
#      Time UTC  Aerosol T (C)  SS.Water (%)  SS. Ice (%)  IN Conc (cm-3)
# 0    19:54:00         -23.85        -20.93         0.00             NaN
# 1    19:55:00         -23.88        -20.95         0.00             NaN
# 2    19:56:00         -23.74        -20.84         0.00             NaN
# 3    19:57:00         -23.56        -20.70         0.00             NaN
# 4    19:58:00         -23.44        -20.61         0.00             NaN
# ..        ...            ...           ...          ...             ...
# 218  23:32:00         -20.68         -9.11        12.10             NaN
# 219  23:33:00         -20.61         -8.93        12.25             NaN
# 220  23:34:00         -17.66        -12.93         3.88             NaN
# 221  23:35:00         -16.25        -14.76         0.00             NaN
# 222  23:36:00         -16.08        -14.62         0.00             NaN
#
# [223 rows x 5 columns]

# %%
df = df.dropna(subset=['IN Conc (cm-3)', 'Aerosol T (C)'])  # 删除IN浓度或温度为NaN的行
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 82 entries, 35 to 212
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Time UTC        82 non-null     object
#  1   Aerosol T (C)   82 non-null     float64
#  2   SS.Water (%)    82 non-null     float64
#  3   SS. Ice (%)     82 non-null     float64
#  4   IN Conc (cm-3)  82 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 3.8+ KB
#      Time UTC  Aerosol T (C)  SS.Water (%)  SS. Ice (%)  IN Conc (cm-3)
# 35   20:29:00         -24.50         -6.27        19.73        0.000037
# 37   20:31:00         -24.37         -6.23        19.63        0.000115
# 38   20:32:00         -16.46        -14.93         0.00        0.003230
# 39   20:33:00         -16.40        -14.88         0.00        0.002190
# 46   20:40:00         -16.43        -14.91         0.00        0.002670
# ..        ...            ...           ...          ...             ...
# 190  23:04:00         -25.29         -5.88        20.74        0.000884
# 191  23:05:00         -26.11         -3.61        24.64        0.000184
# 193  23:07:00         -27.33          0.11        31.02        0.000172
# 196  23:10:00         -18.97        -10.73         8.12        0.000845
# 212  23:26:00         -21.20         -7.72        14.45        0.001240
#
# [82 rows x 5 columns]

# %%
fig, ax = plt.subplots(dpi=500)
ax.set_xlabel('Temperature(℃)')
ax.set_ylabel('INP concentration(cm-3)')# 不知道是不是标况下的INP浓度
ax.tick_params(which='both', top=True, bottom=True, left=True, right=True, direction='in')
ax.set_title('INP concentration vs Temperature')
ax.set_yscale('log')
#df = df.dropna(subset=['IN Conc (cm-3)', 'Aerosol T (C)'])  # 删除IN浓度或温度为NaN的行
x = df['Aerosol T (C)']
y = df['IN Conc (cm-3)']
print(y)
ax.scatter(x, y)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 218   NaN
# 219   NaN
# 220   NaN
# 221   NaN
# 222   NaN
# Name: IN Conc (cm-3), Length: 223, dtype: float64

# %%
df = df.dropna(subset=['IN Conc (cm-3)', 'Aerosol T (C)'])  # 删除IN浓度或温度为NaN的行
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Time UTC        223 non-null    object
#  1   Aerosol T (C)   223 non-null    float64
#  2   SS.Water (%)    223 non-null    float64
#  3   SS. Ice (%)     223 non-null    float64
#  4   IN Conc (cm-3)  223 non-null    object
# dtypes: float64(3), object(2)
# memory usage: 8.8+ KB
# None

# %%
print(df['IN Conc (cm-3)'])
# Out:
# 0                -NaN
# 1                -NaN
# 2                -NaN
# 3                -NaN
# 4                -NaN
#             ...
# 218               NaN
# 219               NaN
# 220               NaN
# 221               NaN
# 222               NaN
# Name: IN Conc (cm-3), Length: 223, dtype: object

# %%
df = df.replace(['-NaN', 'NaN'], np.nan)  # 将 '-NaN' 和 'NaN' 字符串替换为实际的 NaN 值
df = df.dropna(subset=['IN Conc (cm-3)', 'Aerosol T (C)'])  # 删除IN浓度或温度为NaN的行

# %%
print(df['IN Conc (cm-3)'])
# Out:
# 0                -NaN
# 1                -NaN
# 2                -NaN
# 3                -NaN
# 4                -NaN
#             ...
# 218               NaN
# 219               NaN
# 220               NaN
# 221               NaN
# 222               NaN
# Name: IN Conc (cm-3), Length: 223, dtype: object

# %%
df['IN Conc (cm-3)']
# Out:
# 0                -NaN
# 1                -NaN
# 2                -NaN
# 3                -NaN
# 4                -NaN
#             ...
# 218               NaN
# 219               NaN
# 220               NaN
# 221               NaN
# 222               NaN
# Name: IN Conc (cm-3), Length: 223, dtype: object

# %%
df['IN Conc (cm-3)'].dtype
# Out:
# dtype('O')

# %%
y = df['IN Conc (cm-3)'].astype(float)
print(y.max())
print(y.min())
y
# Out:
# 0.0202
# 3.7e-05
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 218   NaN
# 219   NaN
# 220   NaN
# 221   NaN
# 222   NaN
# Name: IN Conc (cm-3), Length: 223, dtype: float64
