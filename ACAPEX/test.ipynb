# %%
import pathlib
import icartt
import matplotlib.pyplot as plt
import numpy as np

# %%
wd = pathlib.Path(r"D:\Coding\Data\ACAPEX\demott-cfdc\CFDC_ACAPEX_20150116_R1.ict")
ict = icartt.Dataset(wd)
# Out:
# c:\Users\admin\.conda\envs\hongyu\Lib\site-packages\icartt\dataset.py:290: UserWarning: Normal comments: required keyword ASSOCIATED_DATA is missing.
#   warnings.warn(
# c:\Users\admin\.conda\envs\hongyu\Lib\site-packages\icartt\dataset.py:290: UserWarning: Normal comments: required keyword DATA_INFO is missing.
#   warnings.warn(
# c:\Users\admin\.conda\envs\hongyu\Lib\site-packages\icartt\dataset.py:692: UserWarning: Number of header lines suggested in line 1 (41) do not match actual header lines read (43)
#   warnings.warn(

# %%
ict.PIName
# Out:
# 'Levin, Ezra'

# %%
ict.PIAffiliation
# Out:
# 'Colorado State University'

# %%
ict.missionName
# Out:
# 'ACAPEX'

# %%
ict.dataSourceDescription
# Out:
# 'CFDC'

# %%
ict.dataID
# Out:
# 'CFDC'

# %%
ict.locationID
# Out:
# 'ACAPEX'

# %%
[x for x in ict.variables]
# Out:
# ['start_time',
#  'stop_time',
#  'Lat',
#  'Lon',
#  'Alt',
#  'N_INP',
#  'sigma_INP',
#  'CL_flag',
#  'P',
#  'T',
#  'SSw',
#  'inlet_flag']
