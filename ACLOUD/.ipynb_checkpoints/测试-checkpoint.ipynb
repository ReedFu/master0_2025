# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_table(r"D:\Data\ACLOUD\Mertes-etal_2019\datasets\P6_206_ACLOUD_2017_1705270601_aerosol_particles.tab", skiprows=122)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4208 entries, 0 to 4207
# Columns: 108 entries, Date/Time to dN/dlogDp [#/cm**3] (1000 nm)
# dtypes: float64(105), int64(2), object(1)
# memory usage: 3.5+ MB

# %%
df.columns
# Out:
# Index(['Date/Time', 'Altitude [m] (m a.s.l.)', 'Longitude', 'Latitude',
#        'PPPP [hPa] (CVI)', 'TTT [°C] (CVI, recalculated from K (-27...)',
#        'Flag (CVI)', 'EF (CVI)', 'Ø [µm] (CVI lower cut-off diameter)',
#        'ac [1/m]',
#        ...
#        'dN/dlogDp [#/cm**3] (768.22 nm)', 'dN/dlogDp [#/cm**3] (791.06 nm)',
#        'dN/dlogDp [#/cm**3] (814.58 nm)', 'dN/dlogDp [#/cm**3] (838.8 nm)',
#        'dN/dlogDp [#/cm**3] (863.74 nm)', 'dN/dlogDp [#/cm**3] (889.42 nm)',
#        'dN/dlogDp [#/cm**3] (915.86 nm)', 'dN/dlogDp [#/cm**3] (943.09 nm)',
#        'dN/dlogDp [#/cm**3] (971.13 nm)', 'dN/dlogDp [#/cm**3] (1000 nm)'],
#       dtype='object', length=108)

# %%
df['CP_conc [#/cm**3]']
# Out:
# 0       0.000
# 1       0.000
# 2       0.033
# 3       0.000
# 4       0.000
#         ...
# 4203      NaN
# 4204      NaN
# 4205      NaN
# 4206      NaN
# 4207      NaN
# Name: CP_conc [#/cm**3], Length: 4208, dtype: float64

# %%
print(max(df['CP_conc [#/cm**3]']))
print(min(df['CP_conc [#/cm**3]']))
# Out:
# 3389.514
# 0.0
